# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.cluster import hierarchy
from sklearn.preprocessing import MinMaxScaler
import os, glob, inspect, sys


currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
from epri_mc_lib import *

# %% [markdown]
# # Import data

# %%
data_path = "../Data/Merged_data" #add ../ at the beginning of the str if you need to go up a directory
df = pd.read_csv(os.path.join(data_path, 'ALL_TUBE_PIPE_merge_1.csv'), 
                 index_col=0)
df.head()
# Out:
#       TEP_mean_uV_C  TEP_error_uV_C  Absorption_avg_500  Absorption_std_500  \
# T_B1      12.947951        0.073112            0.000234            0.000018
# T_B2      12.920068        0.077814            0.000571            0.000139
# T_B3      12.932865        0.088762            0.000244            0.000030
# T_B4      10.763517        0.071173            0.000379            0.000100
# T_B5      12.942958        0.074808            0.000230            0.000033
#
#       backscatter_avg  backscatter_std  Absorption_avg_50  Absorption_std_50  \
# T_B1           0.0175           0.0042           0.001264           0.000519
# T_B2           0.0240           0.0057           0.002486           0.000816
# T_B3           0.0134           0.0028           0.001168           0.000555
# T_B4           0.0146           0.0031           0.002084           0.000648
# T_B5           0.0182           0.0040           0.001141           0.000447
#
#                  A         A std  ...  Absorption_avg_100  Absorption_std_100  \
# T_B1  4.410000e-13  4.090000e-07  ...            0.000682            0.000193
# T_B2  1.520000e-06  1.510000e-06  ...            0.001069            0.000365
# T_B3  4.270000e-13  5.640000e-07  ...            0.000658            0.000246
# T_B4  7.580000e-07  1.000000e-06  ...            0.000921            0.000223
# T_B5  3.970000e-13  4.670000e-07  ...            0.000571            0.000113
#
#       Absorption_avg_200  Absorption_std_200  median_CF  median_perm  \
# T_B1            0.000373            0.000094     1.1000        68.50
# T_B2            0.000874            0.000234     1.1095        66.45
# T_B3            0.000349            0.000078     1.0795        68.40
# T_B4            0.000701            0.000136     4.5140        32.90
# T_B5            0.000397            0.000088     1.4290        64.95
#
#       median_MBN  median_CF_g  median_perm_g  median_pMBN_g
# T_B1      0.4730          NaN            NaN            NaN
# T_B2      0.6305          NaN            NaN            NaN
# T_B3      0.5765          NaN            NaN            NaN
# T_B4      0.5005          NaN            NaN            NaN
# T_B5      0.5380          NaN            NaN            NaN
#
# [5 rows x 24 columns]

# %%
# dummy column dropping TO USE ONLY IF NEED
drop_cols = ['Absorption_avg_500',
            'Absorption_std_500',
            'backscatter_std',
            'Absorption_avg_200',
            'Absorption_std_200',
            'median_CF_g',
            'median_perm_g',
            'median_pMBN_g']
df = df.drop(columns=drop_cols)

# %%
#or dummy drop na TO USE ONLY IF NEED
df.dropna(how='all', axis=1, inplace=True) #to drop all columns without data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, T_B1 to P_N
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   TEP_mean_uV_C       24 non-null     float64
#  1   TEP_error_uV_C      24 non-null     float64
#  2   backscatter_avg     24 non-null     float64
#  3   Absorption_avg_50   24 non-null     float64
#  4   Absorption_std_50   24 non-null     float64
#  5   A                   24 non-null     float64
#  6   A std               24 non-null     float64
#  7   B                   24 non-null     float64
#  8   B std               24 non-null     float64
#  9   p                   24 non-null     float64
#  10  p std               24 non-null     float64
#  11  Absorption_avg_100  24 non-null     float64
#  12  Absorption_std_100  24 non-null     float64
#  13  median_CF           24 non-null     float64
#  14  median_perm         24 non-null     float64
#  15  median_MBN          24 non-null     float64
# dtypes: float64(16)
# memory usage: 3.2+ KB

# %% [markdown]
# ## Selecting sub samples

# %%
#select pipe and tube without Nan
pipe = df.copy().iloc[16:]
pipe.dropna(how='all', axis=1, inplace=True)

tube = df.copy().iloc[:16]
tube.dropna(how='all', axis=1, inplace=True)
v
tube_wo_blind = df.copy().iloc[8:16]
tube_wo_blind.dropna(how='all', axis=1, inplace=True)

tube_blind = df.copy().iloc[:]
tube_blind.dropna(how='all', axis=1, inplace=True)

# %% [markdown]
# ## Scaling values

# %%
scaler = MinMaxScaler()
scaled_df = scaler.fit_transform(df)

#if need reapply selecting sub samples with scaler
