# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob

# %%
data_path = "../../Data/Merged_data"
df = pd.read_csv(os.path.join(data_path, 'ALL_TUBE_PIPE_merge_1.csv'))
df.head()
# Out:
#   Unnamed: 0  TEP_mean_uV_C  TEP_error_uV_C  Absorption_avg_500  \
# 0       T_B1      12.947951        0.073112            0.000234
# 1       T_B2      12.920068        0.077814            0.000571
# 2       T_B3      12.932865        0.088762            0.000244
# 3       T_B4      10.763517        0.071173            0.000379
# 4       T_B5      12.942958        0.074808            0.000230
#
#    Absorption_std_500  backscatter_avg  backscatter_std  Absorption_avg_50  \
# 0            0.000018           0.0175           0.0042           0.001264
# 1            0.000139           0.0240           0.0057           0.002486
# 2            0.000030           0.0134           0.0028           0.001168
# 3            0.000100           0.0146           0.0031           0.002084
# 4            0.000033           0.0182           0.0040           0.001141
#
#    Absorption_std_50             A  ...  Absorption_avg_100  \
# 0           0.000519  4.410000e-13  ...            0.000682
# 1           0.000816  1.520000e-06  ...            0.001069
# 2           0.000555  4.270000e-13  ...            0.000658
# 3           0.000648  7.580000e-07  ...            0.000921
# 4           0.000447  3.970000e-13  ...            0.000571
#
#    Absorption_std_100  Absorption_avg_200  Absorption_std_200  median_CF  \
# 0            0.000193            0.000373            0.000094     1.1000
# 1            0.000365            0.000874            0.000234     1.1095
# 2            0.000246            0.000349            0.000078     1.0795
# 3            0.000223            0.000701            0.000136     4.5140
# 4            0.000113            0.000397            0.000088     1.4290
#
#    median_perm  median_MBN  median_CF_g  median_perm_g  median_pMBN_g
# 0        68.50      0.4730          NaN            NaN            NaN
# 1        66.45      0.6305          NaN            NaN            NaN
# 2        68.40      0.5765          NaN            NaN            NaN
# 3        32.90      0.5005          NaN            NaN            NaN
# 4        64.95      0.5380          NaN            NaN            NaN
#
# [5 rows x 25 columns]

# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
from epri_mc_lib import *

# %%
df = add_col_TEP_plus_1(df)
df[['TEP_mean_uV_C', 'TEP_plus_1']].head()
# Out:
#    TEP_mean_uV_C  TEP_plus_1
# 0      12.947951   13.947951
# 1      12.920068   13.920068
# 2      12.932865   13.932865
# 3      10.763517   11.763517
# 4      12.942958   13.942958
