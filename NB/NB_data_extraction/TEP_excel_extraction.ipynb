# %%
import pandas as pd
import os

# %%
excel_pipe = os.path.join(os.path.dirname(os.getcwd()),'../Data/Raw_data/TEP_Data_PipeSections.xlsx')
excel_tube = os.path.join(os.path.dirname(os.getcwd()),'../Data/Raw_data/TEP_Data_Tubes.xlsx')

tep_pipe = pd.read_excel(excel_pipe, sheet_name = None)
tep_tube = pd.read_excel(excel_tube, sheet_name = None)

output_pipe = os.path.join(os.path.dirname(os.getcwd()),'../Data/Intermediate_data/PIPE_tep_summary.csv')
output_tube = os.path.join(os.path.dirname(os.getcwd()),'../Data/Intermediate_data/TUBE_tep_summary.csv')

# %%
tep_pipe.keys()
# Out:
# dict_keys(['specimens & settings', 'summary', 'P1a', 'P1b', 'P2a', 'P2b', 'P3a', 'P3b', 'P4a', 'P4b', 'P5a', 'P5b', 'P6a', 'P6b', 'P7a', 'P7b', 'P8a', 'P8b'])

# %%
tep_tube.keys()
# Out:
# dict_keys(['specimens & settings', 'summary', 'B1a', 'B1b', 'B2a', 'B2b', 'B3a', 'B3b', 'B4a', 'B4b', 'B5a', 'B5b', 'B6a', 'B6b', 'B7a', 'B7b', 'B8a', 'B8b', 'T1a', 'T1b', 'T2a', 'T2b', 'T3a', 'T3b', 'T4a', 'T4b', 'T5a', 'T5b', 'T6a', 'T6b', 'T7a', 'T7b', 'T8a', 'T8b'])

# %%
tep_settings = tep_pipe['specimens & settings']
tep_settings = tep_settings.loc[8:,["ID","Heat Treatment"]]
tep_settings
# Out:
#         ID   Heat Treatment
# 8   T1, P1      As Received
# 9   T2, P2       Normalized
# 10  T3, P3  Norm + Tempered
# 11  T4, P4         Tempered
# 12  T5, P5    Over Tempered
# 13  T6, P6   Full Ferrittic
# 14  T7. P7              HAZ
# 15  T8, P8   HAZ + Tempered

# %%
tep_tube_summary = tep_tube['summary'].iloc[4:,:11]
col_rename = tep_tube_summary.loc[:4,:].values.tolist()[0]
col_rename = [i+j for i,j in zip (col_rename,["","","","_uV_C","_uV_C","_uV_C","_uV_C","_uV_C","_uV_C","_uV_C","_uV_C"])]
col_rename[1] = "serial"
tep_tube_summary.columns = col_rename
tep_tube_summary = tep_tube_summary.drop([4,5,22,23,24,25])
tep_tube_summary.insert(loc=1, column="condition", value=["unknown"]*8 + tep_settings["Heat Treatment"].tolist())
tep_tube_summary.to_csv(output_tube,index=False)
tep_tube_summary
# Out:
#    material        condition serial         HV  a1_uV_C  a2_uV_C  b1_uV_C  \
# 6        B1          unknown      1  not known  12.9414  12.9606  12.9374
# 7        B2          unknown      2  not known  12.9212  12.9353  12.8961
# 8        B3          unknown      3  not known  12.9422  12.9209  12.9025
# 9        B4          unknown      4  not known  10.7699  10.7552   10.762
# 10       B5          unknown      5  not known  12.9282  12.9557  12.9357
# 11       B6          unknown      6  not known  11.0772  11.0149  11.0179
# 12       B7          unknown      7  not known  12.8512  12.9174  12.8529
# 13       B8          unknown      8  not known  12.2666  12.2276  12.2718
# 14       T1      As Received      9        220  12.9252  12.9398  12.9349
# 15       T2       Normalized     10        428  10.7881  10.7998  10.8067
# 16       T3  Norm + Tempered     11        208  12.9049  12.9356  12.8986
# 17       T4         Tempered     12        207  12.9426  12.9346  12.9191
# 18       T5    Over Tempered     13        198  12.2706  12.3206  12.2687
# 19       T6   Full Ferrittic     14        147  12.8496  12.8994  12.8314
# 20       T7              HAZ     15        405  10.9938  11.0115  11.0172
# 21       T8   HAZ + Tempered     16        170   12.969  12.9755  12.9507
#
#     b2_uV_C average_uV_C max diff_uV_C  stdev_uV_C error_uV_C
# 6   12.9524       12.948     0.0231944   0.0105513  0.0731117
# 7   12.9278      12.9201     0.0391736   0.0169927   0.077814
# 8   12.9658      12.9329      0.063267   0.0272888  0.0887621
# 9   10.7669      10.7635     0.0147426  0.00643435  0.0711731
# 10  12.9523       12.943     0.0275493   0.0131926  0.0748076
# 11  11.0412      11.0378     0.0623269   0.0287874  0.0906358
# 12  12.9072      12.8822     0.0662222   0.0350501  0.0990659
# 13  12.2652      12.2578     0.0441156   0.0202978  0.0809197
# 14  12.9882       12.947     0.0630043   0.0281142  0.0897866
# 15  10.8259      10.8051     0.0378312   0.0158486  0.0768421
# 16  12.9189      12.9145     0.0369972   0.0164287  0.0773279
# 17  12.9345      12.9327     0.0234646  0.00981471  0.0727002
# 18   12.337      12.2992     0.0682174    0.034794   0.098704
# 19  12.8827      12.8658     0.0679771   0.0308686  0.0933353
# 20  11.0186      11.0103     0.0248282   0.0114256  0.0736355
# 21  13.0011      12.9741     0.0504478   0.0208723  0.0815022

# %%
tep_pipe_summary = tep_pipe['summary'].iloc[5:,:11]
col_rename = tep_pipe_summary.loc[:5,:].values.tolist()[0]
col_rename = [i+j for i,j in zip (col_rename,["","","","_uV_C","_uV_C","_uV_C","_uV_C","_uV_C","_uV_C","_uV_C","_uV_C"])]
col_rename[1] = "serial"
tep_pipe_summary.columns = col_rename
tep_pipe_summary = tep_pipe_summary.drop([5,6])
tep_pipe_summary = tep_pipe_summary[:8]
tep_pipe_summary.insert(loc=1, column="condition", value=tep_settings["Heat Treatment"].tolist())
tep_pipe_summary.to_csv(output_pipe,index=False)
tep_pipe_summary
# Out:
#    material        condition serial   HV  a1_uV_C  a2_uV_C  b1_uV_C  b2_uV_C  \
# 7        P1      As Received      1  220  13.1961  13.1336  13.1311  13.0935
# 8        P2       Normalized      2  428  10.8085  10.8272  10.8247  10.8256
# 9        P3  Norm + Tempered      3  208  13.1074  13.0909  13.1425   13.131
# 10       P4         Tempered      4  207  13.1594  13.1434  13.1566  13.1415
# 11       P5    Over Tempered      5  198  13.1876  13.1709  13.1626  13.1588
# 12       P6   Full Ferrittic      6  147  13.0675  12.9982  13.0263  12.9942
# 13       P7              HAZ      7  405  11.7455  11.5988  11.7491  11.6378
# 14       P8   HAZ + Tempered      8  170  13.1641  13.1226  13.1541  13.1285
#
#    average_uV_C max diff_uV_C  stdev_uV_C error_uV_C
# 7       13.1386      0.102626   0.0425245   0.131276
# 8       10.8215     0.0186878  0.00871313   0.101507
# 9        13.118     0.0515896   0.0232034   0.110243
# 10      13.1502      0.017896  0.00906219   0.101629
# 11        13.17      0.028856   0.0128089   0.103229
# 12      13.0216     0.0732782   0.0337812   0.120684
# 13      11.6828      0.150262    0.076152   0.182199
# 14      13.1423     0.0415097   0.0199645   0.107677
