# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys, inspect
from sklearn.preprocessing import StandardScaler, MinMaxScaler

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
import epri_mc_lib_2 as mc
from importlib import reload
reload(mc)
# Out:
# <module 'epri_mc_lib_2' from '/home/nick/Bureau/Programming/S2DS/Oct20_EPRI/Task2/NB/epri_mc_lib_2.py'>

# %%
data = pd.read_csv(os.path.join(os.path.dirname(os.getcwd()), '../Data/Extracted_data/UT_backscattering_up.csv'),
                    index_col=0)

# %%
test_data = data[["Backscattering Amplitude","% change from 0% CW","Backscattering Amplitude.1","% change from 0% CW.1","Backscattering Amplitude.2","% change from 0% CW.2","Backscattering Amplitude.3","% change from 0% CW.3"]]
for col in ["% change from 0% CW","% change from 0% CW.1","% change from 0% CW.2","% change from 0% CW.3"]:
    test_data[col] = test_data[col].str.replace("%", "")
test_data
# Out:
# /home/nick/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                  Backscattering Amplitude % change from 0% CW  \
# Sample ID
# 304, 0% - 1 CW                       11.1                   0
# 304, 20% - 1 CW                       9.8                 -12
# 304, 40% - 1 CW                       8.9                 -20
# 304, 60% - 1 CW                      11.4                   3
# 304, 80% - 1 CW                      12.2                  10
#
#                  Backscattering Amplitude.1 % change from 0% CW.1  \
# Sample ID
# ...

# %%
mc.scale_general(test_data, MinMaxScaler())[0]
# Out:
#                  Backscattering Amplitude  % change from 0% CW  \
# Sample ID
# 304, 0% - 1 CW                   0.666667             0.666667
# 304, 20% - 1 CW                  0.272727             0.266667
# 304, 40% - 1 CW                  0.000000             0.000000
# 304, 60% - 1 CW                  0.757576             0.766667
# 304, 80% - 1 CW                  1.000000             1.000000
#
#                  Backscattering Amplitude.1  % change from 0% CW.1  \
# Sample ID
# 304, 0% - 1 CW                     0.694262               0.696970
# 304, 20% - 1 CW                    1.000000               1.000000
# 304, 40% - 1 CW                    0.347131               0.353535
# 304, 60% - 1 CW                    0.119473               0.121212
# 304, 80% - 1 CW                    0.000000               0.000000
#
#                  Backscattering Amplitude.2  % change from 0% CW.2  \
# Sample ID
# 304, 0% - 1 CW                     1.000000               1.000000
# ...
